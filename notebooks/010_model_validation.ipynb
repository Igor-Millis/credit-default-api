# %%
# ============================================================
# 20. HIPERPARÂMETROS DO XGBOOST TUNED
# ============================================================

best_params = {
    "colsample_bytree": 0.8,
    "learning_rate": 0.05,
    "max_depth": 7,
    "min_child_weight": 5,
    "n_estimators": 100,
    "reg_lambda": 5,
    "subsample": 0.8
}

# %%
# ============================================================
# 1. IMPORTS
# ============================================================

import os
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ==================================================
# Leitura dos dados
# ==================================================

TARGET = "default payment next month"

df = pd.read_excel(
    r"C:\Users\T-Gamer\Desktop\igor\credit-default-api\data\raw\default_of_credit_card_clients.xls",
    header=1
)

# ============================================================
# 3. SEPARAÇÃO ENTRE FEATURES E TARGET
# ============================================================

X = df.drop(columns=["ID", TARGET])

y = df[TARGET]

print("=" * 60)
print("Dataset")
print("=" * 60)

print(f"Número de observações : {df.shape[0]}")
print(f"Número de variáveis   : {X.shape[1]}")

# ============================================================
# 4. SEPARAÇÃO TREINO / TESTE
# ============================================================

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    stratify=y,
    random_state=42
)

print("\nTreino:", X_train.shape)
print("Teste :", X_test.shape)
# Out:
# ...
# Dataset
# ...
# Número de observações : 30000
# Número de variáveis   : 23
#
# Treino: (24000, 23)
# Teste : (6000, 23)

# %%
# ============================================================
# IMPORTS - VALIDAÇÃO
# ============================================================

from sklearn.model_selection import train_test_split

# ============================================================
# 21. TREINO x VALIDAÇÃO
# ============================================================

X_model_train, X_val, y_model_train, y_val = train_test_split(
    X_train,
    y_train,
    test_size=0.20,
    stratify=y_train,
    random_state=42
)

print("Treino do modelo :", X_model_train.shape)
print("Validação        :", X_val.shape)
print("Teste final      :", X_test.shape)
# Out:
# Treino do modelo : (19200, 23)
# Validação        : (4800, 23)
# Teste final      : (6000, 23)

# %%
# ==================================================
# Pré-processamento
# ==================================================

preprocessor = create_preprocessor()


# ==================================================
# Pipeline
# ==================================================

pipeline = Pipeline(
    steps=[
        (
            "preprocessor",
            preprocessor
        ),
        (
            "classifier",
            XGBClassifier(
                n_estimators=100,
                max_depth=6,
                learning_rate=0.1,
                subsample=1.0,
                colsample_bytree=1.0,
                objective="binary:logistic",
                eval_metric="logloss",
                random_state=42,
                n_jobs=-1
            )
        )
    ]
)

xgb_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", XGBClassifier(...))
])

# %%
# ==================================================
# XGBoost - Baseline
# ==================================================

import os
import sys
import joblib
import pandas as pd

from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report,
    confusion_matrix
)

from xgboost import XGBClassifier

# ==================================================
# Configuração do projeto
# ==================================================

PROJECT_ROOT = os.path.abspath("..")

if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

from src.preprocessing import create_preprocessor

# ==================================================
# Leitura dos dados
# ==================================================

TARGET = "default payment next month"

df = pd.read_excel(
    r"C:\Users\T-Gamer\Desktop\igor\credit-default-api\data\raw\default_of_credit_card_clients.xls",
    header=1
)


# ==================================================
# Separação entre features e target
# ==================================================

X = df.drop(columns=["ID", TARGET])

y = df[TARGET]


print("=" * 60)
print("Dataset")
print("=" * 60)

print(f"Número de observações : {df.shape[0]}")
print(f"Número de variáveis   : {X.shape[1]}")


# ==================================================
# Train Test Split
# ==================================================

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    stratify=y,
    random_state=42
)


print("\nTreino:", X_train.shape)
print("Teste :", X_test.shape)


# ==================================================
# Pré-processamento
# ==================================================

preprocessor = create_preprocessor()


# ==================================================
# Pipeline
# ==================================================

pipeline = Pipeline(
    steps=[
        (
            "preprocessor",
            preprocessor
        ),
        (
            "classifier",
            XGBClassifier(
                n_estimators=100,
                max_depth=6,
                learning_rate=0.1,
                subsample=1.0,
                colsample_bytree=1.0,
                objective="binary:logistic",
                eval_metric="logloss",
                random_state=42,
                n_jobs=-1
            )
        )
    ]
)

xgb_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", XGBClassifier(...))
])
# Out:
# ...
# Dataset
# ...
# Número de observações : 30000
# Número de variáveis   : 23
#
# Treino: (24000, 23)
# Teste : (6000, 23)
# c:\Users\T-Gamer\Desktop\igor\credit-default-api\.venv\Lib\site-packages\xgboost\core.py:550: FutureWarning: Pass `objective` as keyword args.
#   warnings.warn(msg, FutureWarning)

# %%
# ============================================================
# 22. XGBOOST TUNED
# ============================================================

from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier

# ============================================================
# Hiperparâmetros encontrados pelo Grid Search
# ============================================================

best_params = {
    "colsample_bytree": 0.8,
    "learning_rate": 0.05,
    "max_depth": 7,
    "min_child_weight": 5,
    "n_estimators": 100,
    "reg_lambda": 5,
    "subsample": 0.8
}

# ============================================================
# Pré-processador
# ============================================================

preprocessor = create_preprocessor()

# ============================================================
# Pipeline XGBoost Tuned
# ============================================================

xgb_tuned_pipeline = Pipeline(
    steps=[
        (
            "preprocessor",
            preprocessor
        ),
        (
            "classifier",
            XGBClassifier(
                **best_params,
                objective="binary:logistic",
                eval_metric="logloss",
                random_state=42,
                n_jobs=-1
            )
        )
    ]
)

print("=" * 60)
print("XGBoost Tuned")
print("=" * 60)

print("\nHiperparâmetros:")
for parameter, value in best_params.items():
    print(f"{parameter}: {value}")
# Out:
# ...
# XGBoost Tuned
# ...
#
# Hiperparâmetros:
# colsample_bytree: 0.8
# learning_rate: 0.05
# max_depth: 7
# min_child_weight: 5
# n_estimators: 100
# reg_lambda: 5
# subsample: 0.8

# %%
# ============================================================
# 23. TREINAMENTO DO XGBOOST TUNED
# ============================================================

print("=" * 60)
print("TREINAMENTO - XGBoost Tuned")
print("=" * 60)

xgb_tuned_pipeline.fit(
    X_model_train,
    y_model_train
)

print("\nTreinamento concluído.")
# Out:
# ...
# TREINAMENTO - XGBoost Tuned
# ...
#
# Treinamento concluído.

# %%
# ============================================================
# 24. PROBABILIDADES - VALIDAÇÃO
# ============================================================

y_val_proba = xgb_tuned_pipeline.predict_proba(X_val)[:, 1]

print("=" * 60)
print("PROBABILIDADES - VALIDAÇÃO")
print("=" * 60)

print(f"Menor probabilidade : {y_val_proba.min():.4f}")
print(f"Maior probabilidade : {y_val_proba.max():.4f}")
# Out:
# ...
# PROBABILIDADES - VALIDAÇÃO
# ...
# Menor probabilidade : 0.0209
# Maior probabilidade : 0.8997

# %%
# ============================================================
# 25. SELEÇÃO DO THRESHOLD
# ============================================================

from sklearn.metrics import f1_score

thresholds = np.arange(0.10, 0.91, 0.01)

results_threshold = []

for threshold in thresholds:

    y_val_pred = (y_val_proba >= threshold).astype(int)

    f1 = f1_score(
        y_val,
        y_val_pred
    )

    results_threshold.append(
        {
            "threshold": threshold,
            "f1": f1
        }
    )

threshold_results = pd.DataFrame(results_threshold)

best_threshold = threshold_results.loc[
    threshold_results["f1"].idxmax(),
    "threshold"
]

best_f1 = threshold_results.loc[
    threshold_results["f1"].idxmax(),
    "f1"
]

print("=" * 60)
print("THRESHOLD OTIMIZADO")
print("=" * 60)

print(f"Melhor threshold : {best_threshold:.2f}")
print(f"Melhor F1        : {best_f1:.4f}")
# Out:
# ...
# THRESHOLD OTIMIZADO
# ...
# Melhor threshold : 0.24
# Melhor F1        : 0.5405

# %%
# ============================================================
# 26. AVALIAÇÃO - VALIDAÇÃO
# ============================================================

y_val_pred = (
    y_val_proba >= best_threshold
).astype(int)

accuracy_val = accuracy_score(
    y_val,
    y_val_pred
)

precision_val = precision_score(
    y_val,
    y_val_pred
)

recall_val = recall_score(
    y_val,
    y_val_pred
)

f1_val = f1_score(
    y_val,
    y_val_pred
)

auc_val = roc_auc_score(
    y_val,
    y_val_proba
)

print("=" * 60)
print("XGBoost Tuned - Validação")
print("=" * 60)

print(f"Threshold : {best_threshold:.2f}")
print(f"Accuracy  : {accuracy_val:.4f}")
print(f"Precision : {precision_val:.4f}")
print(f"Recall    : {recall_val:.4f}")
print(f"F1        : {f1_val:.4f}")
print(f"ROC AUC   : {auc_val:.4f}")

print("\nMatriz de Confusão:")
print(confusion_matrix(y_val, y_val_pred))

print("\nClassification Report:")
print(
    classification_report(
        y_val,
        y_val_pred
    )
)
# Out:
# ...
# XGBoost Tuned - Validação
# ...
# Threshold : 0.24
# Accuracy  : 0.7729
# Precision : 0.4893
# Recall    : 0.6036
# F1        : 0.5405
# ROC AUC   : 0.7833
#
# Matriz de Confusão:
# [[3069  669]
#  [ 421  641]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      3738
#            1       0.49      0.60      0.54      1062
#
#     accuracy                           0.77      4800
#    macro avg       0.68      0.71      0.69      4800
# weighted avg       0.79      0.77      0.78      4800

# %%
# ============================================================
# 27. MODELO FINAL
# ============================================================

print("=" * 60)
print("TREINAMENTO DO MODELO FINAL")
print("=" * 60)

final_preprocessor = create_preprocessor()

final_xgb_pipeline = Pipeline(
    steps=[
        (
            "preprocessor",
            final_preprocessor
        ),
        (
            "classifier",
            XGBClassifier(
                **best_params,
                objective="binary:logistic",
                eval_metric="logloss",
                random_state=42,
                n_jobs=-1
            )
        )
    ]
)

final_xgb_pipeline.fit(
    X_train,
    y_train
)

print("\nModelo final treinado.")
print(f"Threshold utilizado: {best_threshold:.2f}")
# Out:
# ...
# TREINAMENTO DO MODELO FINAL
# ...
#
# Modelo final treinado.
# Threshold utilizado: 0.24

# %%
# ============================================================
# 28. AVALIAÇÃO FINAL - TESTE
# ============================================================

y_test_proba = final_xgb_pipeline.predict_proba(X_test)[:, 1]

y_test_pred = (
    y_test_proba >= best_threshold
).astype(int)

# %%
# ============================================================
# 29. MÉTRICAS FINAIS
# ============================================================

accuracy_test = accuracy_score(
    y_test,
    y_test_pred
)

precision_test = precision_score(
    y_test,
    y_test_pred
)

recall_test = recall_score(
    y_test,
    y_test_pred
)

f1_test = f1_score(
    y_test,
    y_test_pred
)

auc_test = roc_auc_score(
    y_test,
    y_test_proba
)

print("=" * 60)
print("XGBoost Tuned - RESULTADO FINAL")
print("=" * 60)

print(f"Threshold : {best_threshold:.2f}")
print(f"Accuracy  : {accuracy_test:.4f}")
print(f"Precision : {precision_test:.4f}")
print(f"Recall    : {recall_test:.4f}")
print(f"F1        : {f1_test:.4f}")
print(f"ROC AUC   : {auc_test:.4f}")

print("\nMatriz de Confusão:")
print(confusion_matrix(y_test, y_test_pred))

print("\nClassification Report:")
print(
    classification_report(
        y_test,
        y_test_pred
    )
)
# Out:
# ...
# XGBoost Tuned - RESULTADO FINAL
# ...
# Threshold : 0.24
# Accuracy  : 0.7733
# Precision : 0.4899
# Recall    : 0.6006
# F1        : 0.5396
# ROC AUC   : 0.7770
#
# Matriz de Confusão:
# [[3843  830]
#  [ 530  797]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      4673
#            1       0.49      0.60      0.54      1327
#
#     accuracy                           0.77      6000
#    macro avg       0.68      0.71      0.69      6000
# weighted avg       0.79      0.77      0.78      6000

# %%
# ============================================================
# 30. SALVAMENTO DO MODELO FINAL
# ============================================================

MODEL_PATH = os.path.join(
    PROJECT_ROOT,
    "models",
    "xgboost_tuned_pipeline.pkl"
)

joblib.dump(
    final_xgb_pipeline,
    MODEL_PATH
)

print("=" * 60)
print("MODELO SALVO")
print("=" * 60)

print(MODEL_PATH)
# Out:
# ...
# MODELO SALVO
# ...
# c:\Users\T-Gamer\Desktop\igor\credit-default-api\models\xgboost_tuned_pipeline.pkl

# %%
# ============================================================
# 31. SALVAMENTO DO THRESHOLD
# ============================================================

THRESHOLD_PATH = os.path.join(
    PROJECT_ROOT,
    "models",
    "xgboost_tuned_threshold.pkl"
)

joblib.dump(
    best_threshold,
    THRESHOLD_PATH
)

print("\nThreshold salvo em:")
print(THRESHOLD_PATH)
# Out:
# Threshold salvo em:
# c:\Users\T-Gamer\Desktop\igor\credit-default-api\models\xgboost_tuned_threshold.pkl

# %%
import joblib

model = joblib.load(
    "../models/xgboost_tuned_pipeline.pkl"
)

threshold = joblib.load(
    "../models/xgboost_tuned_threshold.pkl"
)

print("Modelo carregado:", type(model))
print("Threshold:", threshold)
# Out:
# Modelo carregado: <class 'sklearn.pipeline.Pipeline'>
# Threshold: 0.23999999999999994

# %%
# ============================================================
# TESTE DE PREDIÇÃO DO MODELO CARREGADO
# ============================================================

import os
import joblib

# ============================================================
# Caminhos
# ============================================================

PROJECT_ROOT = os.path.abspath("..")

MODEL_PATH = os.path.join(
    PROJECT_ROOT,
    "models",
    "xgboost_tuned_pipeline.pkl"
)

THRESHOLD_PATH = os.path.join(
    PROJECT_ROOT,
    "models",
    "xgboost_tuned_threshold.pkl"
)

# ============================================================
# Carregar modelo e threshold
# ============================================================

model_loaded = joblib.load(
    MODEL_PATH
)

threshold_loaded = joblib.load(
    THRESHOLD_PATH
)

# ============================================================
# Selecionar um cliente do conjunto de teste
# ============================================================

cliente_teste = X_test.iloc[[0]]

# ============================================================
# Probabilidade de inadimplência
# ============================================================

probabilidade = model_loaded.predict_proba(
    cliente_teste
)[0, 1]

# ============================================================
# Classificação usando o threshold definitivo
# ============================================================

predicao = int(
    probabilidade >= threshold_loaded
)

# ============================================================
# Resultado
# ============================================================

print("=" * 60)
print("TESTE DE PREDIÇÃO")
print("=" * 60)

print(f"Probabilidade de default : {probabilidade:.4f}")
print(f"Threshold                : {threshold_loaded:.2f}")
print(f"Predição                 : {predicao}")

if predicao == 1:
    print("Classificação            : INADIMPLENTE")
else:
    print("Classificação            : ADIMPLENTE")
# Out:
# ...
# TESTE DE PREDIÇÃO
# ...
# Probabilidade de default : 0.1254
# Threshold                : 0.24
# Predição                 : 0
# Classificação            : ADIMPLENTE
